# %% [markdown]
# # Beginning of presentation
#
# - Questions to the audience:
#     - Who has deployed a ML model to a production env?
#     - Who monitors the model operations?

# %% [markdown]
# # Introduction to MLOps
#
#
# - What is MLOps?
# - Traditional ML development VS MLOps driven ML development

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Indicator(
    domain = {'x': [0, 1], 'y': [0, 1]},
    value = 450,
    mode = "gauge+number+delta",
    title = {'text': "Bot Racism"},
    delta = {'reference': 380},
    gauge = {'axis': {'range': [None, 500]},
            'bar': {'color': "thistle"},
             'steps' : [
                 {'range': [0, 250], 'color': "green"},
                 {'range': [250, 400], 'color': "orange"},
                 {'range': [400, 500], 'color': "red"}
                 ],
             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 350}}))

fig.show()
# Out:
# <div>                            <div id="81ecb48f-68ee-4b61-9573-8971caea87c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81ecb48f-68ee-4b61-9573-8971caea87c2")) {                    Plotly.newPlot(                        "81ecb48f-68ee-4b61-9573-8971caea87c2",                        [{"delta":{"reference":380},"domain":{"x":[0,1],"y":[0,1]},"gauge":{"axis":{"range":[null,500]},"bar":{"color":"thistle"},"steps":[{"color":"green","range":[0,250]},{"color":"orange","range":[250,400]},{"color":"red","range":[400,500]}],"threshold":{"line":{"color":"red","width":4},"thickness":0.75,"value":350}},"mode":"gauge+number+delta","title":{"text":"Bot Racism"},"value":450,"type":"indicator"}],                        {"template":{"data":{"histogram2dcontou
# ...

# %%
from IPython.display import Image
Image(filename='figures/cycle_1.png')

# %% [markdown]
# # MLOps as a new cycle
#
# ## Common pitfall 1
#
# Start with dev, training, deployment (like in cycle above). Quickly you run out of time for the project and model is deployed. But who is monitoring?
#
# Important: Always think of the cycle as an end-to-end process. When adding a new piece: do I still have the end to end flow?
# A better flow would be

# %%
from IPython.display import Image
Image(filename='figures/cycle_2.png')

# %%
# Monitoring ML

from IPython.display import Image
Image(filename='figures/monitoring.png') 


# Typical assets produced in this
# process include the following:
# • Anomalies detected in serving data
# during drift detection
# • Evaluation metrics produced from
# continuous evaluation
# Core MLOps capabilities:
# • Dataset & feature repository
# • Model monitoring
# • ML metadata & artifact repository

# %%
image.png
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14883/474971046.py in <module>
# ----> 1 image.png
#
# NameError: name 'image' is not defined
